# %%
import re
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('yhoo_stats_selenium.xlsx',index_col=0)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                name      ev  trail_pe  fwd_pe  \
# ticker
# MMM                                     3M Company   119.50     19.56   18.76
# ABT                            Abbott Laboratories   234.49     50.00   24.81
# ABBV                                   AbbVie Inc.   262.28     39.68    8.39
# ABMD                                 Abiomed, Inc.    14.34     74.68     NaN
# ACN                                  Accenture plc   162.74     31.22   30.77
# ...                                             ...     ...       ...     ...
# YUM                              Yum! Brands, Inc.    41.64     35.88   26.32
# ZBRA                Zebra Technologies Corporation    26.70     53.72   31.95
# ZBH                   Zimmer Biomet Holdings, Inc.    40.45    819.71   20.20
# ZION    Zions Bancorporation, National Association      NaN     16.42   11.19
# ZTS                                    Zoetis Inc.    77.52     44.45   35.46
#
# ...

# %%
df.dtypes
# Out:
# name          object
# ev           float64
# trail_pe     float64
# fwd_pe       float64
# peg          float64
# px2sales     float64
# px2book      float64
# ev2rev       float64
# ev2ebitda    float64
# dtype: object

# %%
df.sample(10)
# Out:
#                                   name     ev  trail_pe  fwd_pe    peg  \
# ticker
# OKE                       ONEOK, Inc.   32.95     29.14   13.95   2.52
# PPG              PPG Industries, Inc.   31.17     31.56   19.53  33.67
# RSG           Republic Services, Inc.   37.48     28.38   24.39   2.84
# TT             Trane Technologies plc   37.76     37.06   28.65  18.13
# AVY        Avery Dennison Corporation   16.33     26.23   22.27   3.90
# ABC     AmerisourceBergen Corporation   20.21     13.93   12.47   5.94
# CDW                   CDW Corporation   25.94     31.03   23.47    NaN
# PAYX                    Paychex, Inc.   33.07     31.27   29.59   5.53
# AVB       AvalonBay Communities, Inc.   32.33     30.38   46.73   7.37
# MRO          Marathon Oil Corporation   11.05     17.28     NaN    NaN
#
#         px2sales  px2book  ev2rev  ev2ebitda
# ticker
# OKE         2.10     3.10    3.82      16.19
# PPG         2.41     6.38    2.25      15.52
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                name      ev  trail_pe  fwd_pe  \
# ticker
# MMM                                     3M Company   119.50     19.56   18.76
# ABT                            Abbott Laboratories   234.49     50.00   24.81
# ABBV                                   AbbVie Inc.   262.28     39.68    8.39
# ABMD                                 Abiomed, Inc.    14.34     74.68     NaN
# ACN                                  Accenture plc   162.74     31.22   30.77
# ...                                             ...     ...       ...     ...
# YUM                              Yum! Brands, Inc.    41.64     35.88   26.32
# ZBRA                Zebra Technologies Corporation    26.70     53.72   31.95
# ZBH                   Zimmer Biomet Holdings, Inc.    40.45    819.71   20.20
# ZION    Zions Bancorporation, National Association      NaN     16.42   11.19
# ...

# %%
df.to_csv('stats_selenium.csv')
