# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('convert_toy_sample.csv')

# %%
df = pd.DataFrame(data)

# %%
df.dtypes
# Out:
# EBITDA    object
# dtype: object

# %%
df
# Out:
#       EBITDA
# 0      8.92B
# 1         9B
# 2     21.53B
# 3    250.56M
# 4      7.41B
# ..       ...
# 499     1.8B
# 500     785M
# 501       2B
# 502      NaN
# 503    2.78B
#
# [504 rows x 1 columns]

# %%
df[['EBITDA']].apply(split)

# %%
df1.iloc[[0,2], :2]

# %%
eug = df.iloc[2]

# %%
eug
# Out:
# EBITDA    21.53B
# Name: 2, dtype: object

# %%
data2 =

# %%
t = '702.07M'
t2 = '6.21B'

# %%
def split(x):
    x=str(x)
    print(x)
    try:
        num = float(re.findall(r'(.+)([BTM])',x)[0][0])
        scale = re.findall(r'(.+)([BTM])',x)[0][1]
        if scale == "B":
            return num
        elif scale == "T":
            return num*1000
        elif scale == "M":
            return num/1000
    except:
        return x

# %%
data2 = pd.read_csv('yhoo_stats.csv')

# %%
df = pd.DataFrame(data2)

# %%
df['cash'] = df['cash'].map(split)
# Out:
# 5.05B
# 4.73B
# 7.96B
# 486.45M
# 8.68B
# 8.65B
# 5.99B
# 2.29B
# 1.07B
# 1.89B
# nan
# 1.44B
# 6.21B
# 1.1B
# 3.35B
# 702.07M
# 568.53M
# 3B
# 960.84M
# 428.9M
# 189M
# 8.18B
# 136.69B
# 136.69B
# 4.94B
# 84.4B
# 762M
# 6M
# 6.86B
# 618.7M
# 33B
# 23.63B
# 1.63B
# 578M
# 6.85B
# 4.89B
# 1.21B
# 10.65B
# 1.74B
# 1.06B
# 845.21M
# 30.73B
# 1.19B
# 689.6M
# 162M
# 76.83B
# 5.74B
# 2.82B
# 667M
# 2.85B
# 664.6M
# nan
# 9.74B
# 514.08M
# 1.62B
# 1.61B
# 1.71B
# 216.98M
# 252.3M
# 4.13B
# 1.37B
# 937.1B
# 211.51B
# 4.36B
# 3.26B
# nan
# 5.82B
# 1.15B
# 2.61B
# 6.32B
# 25.59B
# 11.2B
# 2.12B
# 1.67B
# nan
# 16.45B
# 7.62B
# 366.2M
# 243.8M
# 170k
# 1.31B
# 722M
# 40.51B
# 3.74B
# 236.64M
# 9.51B
# 3.12B
# 833.1M
# 8.82B
# 337.8M
# 1.48B
# 1.41B
# 1.49B
# 12.38B
# 1.06B
# 1.06B
# 553M
# 57.56B
# 998M
# 6.89B
# 951.6M
# 6.09B
# 183.1M
# 11.51B
# 900M
# 703.17M
# 30.59B
# 979.41B
# 14.95B
# 877.01M
# 732M
# 1.73B
# 168M
# 10.91B
# 2.72B
# 925M
# 11.74B
# 16.23B
# 68M
# 7.86B
# 153M
# 152.9M
# ...

# %%
df['cash']
# Out:
# 0         5.05
# 1         4.73
# 2         7.96
# 3      0.48645
# 4         8.68
#         ...
# 499       0.73
# 500      0.039
# 501     0.8021
# 502       7.65
# 503       3.66
# Name: cash, Length: 504, dtype: object

# %%
df.to_csv('fuckyea.csv')
